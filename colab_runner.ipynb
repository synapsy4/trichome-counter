# %% [markdown]
# #### Colab setup:

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
project_path = "/content/drive/MyDrive/Colab Notebooks/TrichomeCounter"
os.chdir(project_path)

print(os.getcwd())

# %%
# %pip install segmentation_models_pytorch --quiet

# %% [markdown]
# #### Run training:

# %%
# Inspect config
from scripts.utils import load_config
cfg = load_config()
cfg

# %%
# !python -m train
